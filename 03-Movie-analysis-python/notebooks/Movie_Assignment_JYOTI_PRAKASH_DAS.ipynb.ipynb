# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv("Movie+Assignment+Data.csv")
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here

print(movies.columns) # Used to check the names of columns in the Dataframe.
print(movies.shape)   # Used to find the number of rows and columns.
movies.info()         # Used to get a concise summary of Dataframe.
movies.describe()     # Used to generate a statistical summary of numerical columns.
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')
# (5043, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here

movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here

movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here

null_percentages = ((movies.isnull().sum()/len(movies))*100).round(2)
null_percentages
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.28
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 

Drop_Columns = [
    "color", "director_facebook_likes", "actor_1_facebook_likes",
    "actor_2_facebook_likes", "actor_3_facebook_likes", "actor_2_name",
    "cast_total_facebook_likes", "actor_3_name", "duration",
    "facenumber_in_poster", "content_rating", "country",
    "movie_imdb_link", "aspect_ratio", "plot_keywords"
]
# Dropping only columns that exist to avoid KeyError
Columns_To_Drop=[col for col in Drop_Columns if col in movies.columns] 
movies.drop(columns = Columns_To_Drop , inplace =True )
movies.shape   #So, the 15 specified columns mentioned above have been removed.
# Out:
# (5043, 13)

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here

# Columns where null % > 5
cols_with_high_nulls = null_percentages[null_percentages > 5].index.tolist() # ['gross', 'content_rating', 'budget', 'aspect_ratio']

# Columns left after dropping unwanted columns , where null % > 5 
cols_left_with_high_nulls =[col for col in cols_with_high_nulls if col in movies]  # ['gross', 'budget']

# Dropping rows with nulls in those columns
movies.dropna(subset=cols_left_with_high_nulls, inplace=True)

# Checking updated shape
movies.shape
# Out:
# (3891, 13)

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# Write your code for dropping the rows here

print((movies.isnull().sum(axis=1) > 5).value_counts())  # There are no rows having > 5 NaN values.Thus, No Drop of rows needed.

# Inspecting the remaining Columns with null values
movies.isnull().sum()
# Out:
# False    3891
# Name: count, dtype: int64
# director_name             0
# num_critic_for_reviews    1
# gross                     0
# genres                    0
# actor_1_name              3
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  4
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %% [markdown]
# -  ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here

print(movies["language"].value_counts(dropna =False)) # Here, English have the highest frequency ,so its safe to replace it with NaN values in language Column.

# Filling English at the NaN values.
movies["language"].fillna("English", inplace = True )

# Now, checking the language column after filling all NaN values.
movies["language"].value_counts()
# Out:
# language
# English       3707
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Portuguese       5
# Korean           5
# NaN              4
# Norwegian        4
# Danish           3
# Dutch            3
# Persian          3
# Thai             3
# Hebrew           3
# Dari             2
# Indonesian       2
# Aboriginal       2
# Russian          1
# Romanian         1
# Vietnamese       1
# Arabic           1
# Dzongkha         1
# Zulu             1
# Aramaic          1
# Czech            1
# Telugu           1
# Icelandic        1
# Filipino         1
# Hungarian        1
# Maya             1
# Bosnian          1
# Mongolian        1
# Kazakh           1
# Swedish          1
# Name: count, dtype: int64
# language
# English       3711
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# ...

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here

# Checking number of columns with null value percentages.
print(((movies.isnull().sum()/len(movies))*100).round(2))

print(movies.shape) # Earlier it was - (5043, 28) and now it is (3891, 13)

# Thus, the number of retained rows are :-
round((3891/5043)*100,2)  # ~ 77.16
# Out:
# director_name             0.00
# num_critic_for_reviews    0.03
# genres                    0.00
# actor_1_name              0.08
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# gross in million $        0.00
# budget in million $       0.00
# profit                    0.00
# genre_1                   0.00
# genre_2                   0.00
# dtype: float64
# (3856, 16)
# 77.16

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here

movies[['gross in million $', 'budget in million $']] = movies[['gross', 'budget']] / 1000000
movies.drop(["gross","budget"] , axis = 1 , inplace =True) # New columns have been made in million $ , now old columns are not required, so removed it.
movies.head()
# Out:
#        director_name  num_critic_for_reviews                           genres  \
# 0      James Cameron                   723.0  Action|Adventure|Fantasy|Sci-Fi
# 1     Gore Verbinski                   302.0         Action|Adventure|Fantasy
# 2         Sam Mendes                   602.0        Action|Adventure|Thriller
# 3  Christopher Nolan                   813.0                  Action|Thriller
# 5     Andrew Stanton                   462.0          Action|Adventure|Sci-Fi
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 5     Daryl Sabara                               John Carter
#
#    num_voted_users  num_user_for_reviews language  title_year  imdb_score  \
# ...

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here

movies["profit"]= movies["gross in million $"]-movies["budget in million $"]
movies.head()
# Out:
#        director_name  num_critic_for_reviews                           genres  \
# 0      James Cameron                   723.0  Action|Adventure|Fantasy|Sci-Fi
# 1     Gore Verbinski                   302.0         Action|Adventure|Fantasy
# 2         Sam Mendes                   602.0        Action|Adventure|Thriller
# 3  Christopher Nolan                   813.0                  Action|Thriller
# 5     Andrew Stanton                   462.0          Action|Adventure|Sci-Fi
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 5     Daryl Sabara                               John Carter
#
#    num_voted_users  num_user_for_reviews language  title_year  imdb_score  \
# ...

# %%
# Write your code for sorting the dataframe here

movies.sort_values(by = "profit" , ascending = False).head(10)
# Out:
#           director_name  num_critic_for_reviews  \
# 0         James Cameron                   723.0
# 29      Colin Trevorrow                   644.0
# 26        James Cameron                   315.0
# 3024       George Lucas                   282.0
# 3080   Steven Spielberg                   215.0
# 794         Joss Whedon                   703.0
# 17          Joss Whedon                   703.0
# 509        Roger Allers                   186.0
# 240        George Lucas                   320.0
# 66    Christopher Nolan                   645.0
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 3080                             Family|Sci-Fi         Henry Thomas
# ...

# %%
top10 = movies.sort_values(by = "profit" , ascending = False).head(10)
top10
# Out:
#           director_name  num_critic_for_reviews  \
# 0         James Cameron                   723.0
# 29      Colin Trevorrow                   644.0
# 26        James Cameron                   315.0
# 3024       George Lucas                   282.0
# 3080   Steven Spielberg                   215.0
# 794         Joss Whedon                   703.0
# 17          Joss Whedon                   703.0
# 509        Roger Allers                   186.0
# 240        George Lucas                   320.0
# 66    Christopher Nolan                   645.0
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 3080                             Family|Sci-Fi         Henry Thomas
# ...

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`.

# %%
# Write your code for dropping duplicate values here

movies =movies.drop_duplicates() # Dropping all rows duplicates from movies Dataframe.
movies.shape
# Out:
# (3856, 14)

# %%
# Write code for repeating subtask 2 here

top10 = movies.sort_values(by = "profit",ascending =False).head(10)
top10
# Out:
#           director_name  num_critic_for_reviews  \
# 0         James Cameron                   723.0
# 29      Colin Trevorrow                   644.0
# 26        James Cameron                   315.0
# 3024       George Lucas                   282.0
# 3080   Steven Spielberg                   215.0
# 17          Joss Whedon                   703.0
# 509        Roger Allers                   186.0
# 240        George Lucas                   320.0
# 66    Christopher Nolan                   645.0
# 439           Gary Ross                   673.0
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# 3024           Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 3080                             Family|Sci-Fi         Henry Thomas
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'


# Filtered movies with >25,000 votes, then hierarchically sorted by imdb_score and num_voted_users (both descending), and selected top 250.
IMDb_Top_250 = movies[movies["num_voted_users"] >25000].sort_values(by = ["imdb_score","num_voted_users"],ascending =[False,False]).head(250)

IMDb_Top_250["Rank"] = range(1,251)
IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews  \
# 1937        Frank Darabont                   199.0
# 3466  Francis Ford Coppola                   208.0
# 66       Christopher Nolan                   645.0
# 2837  Francis Ford Coppola                   149.0
# 3355     Quentin Tarantino                   215.0
# ...                    ...                     ...
# 4931           John Carney                   232.0
# 3264        Michael Haneke                   447.0
# 2487          George Cukor                    82.0
# 3680             Spike Lee                   103.0
# 2666           James Ivory                    58.0
#
#                             genres      actor_1_name  \
# 1937                   Crime|Drama    Morgan Freeman
# 3466                   Crime|Drama         Al Pacino
# 66     Action|Crime|Drama|Thriller    Christian Bale
# 2837                   Crime|Drama    Robert De Niro
# 3355                   Crime|Drama      Bruce Willis
# ...

# %%
# Extracting all the movies in the IMDb_Top_250 dataframe which are not in the English language and store them in a new dataframe named Top_Foreign_Lang_Film.

Top_Foreign_Lang_Film = IMDb_Top_250[~(IMDb_Top_250["language"] == "English")]
Top_Foreign_Lang_Film.head()
# Out:
#                          director_name  num_critic_for_reviews  \
# 4498                      Sergio Leone                   181.0
# 4029                Fernando Meirelles                   214.0
# 4747                    Akira Kurosawa                   153.0
# 2373                    Hayao Miyazaki                   246.0
# 4259  Florian Henckel von Donnersmarck                   215.0
#
#                                   genres     actor_1_name  \
# 4498                             Western   Clint Eastwood
# 4029                         Crime|Drama      Alice Braga
# 4747              Action|Adventure|Drama  Takashi Shimura
# 2373  Adventure|Animation|Family|Fantasy   Bunta Sugawara
# 4259                      Drama|Thriller   Sebastian Koch
#
#                           movie_title  num_voted_users  num_user_for_reviews  \
# 4498  The Good, the Bad and the Ugly            503509                 780.0
# 4029                     City of God            533200                 749.0
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %%
# No,there is no "Veer-Zaara" word in the dataframe.

Top_Foreign_Lang_Film.isin(["Veer-Zaara"]).any().any()  # First any() checks each column for "Veer-Zaara" and returns a boolean Series,
                                                        # second any() checks if any column contains True, confirming its presence in the DataFrame.
# Out:
# False

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
# Write your code for extracting the top 10 directors here

top10director = movies.groupby("director_name")["imdb_score"].mean().sort_values(ascending =False).head(10)
top10director = top10director.round(1).to_frame()
top10director
# Out:
#                        imdb_score
# director_name
# Charles Chaplin               8.6
# Tony Kaye                     8.6
# Alfred Hitchcock              8.5
# Ron Fricke                    8.5
# Damien Chazelle               8.5
# Majid Majidi                  8.5
# Sergio Leone                  8.4
# Christopher Nolan             8.4
# S.S. Rajamouli                8.4
# Marius A. Markevicius         8.4

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Inspecting the genres Column in the movies DataFrame

movies.head()
# Out:
#        director_name  num_critic_for_reviews                           genres  \
# 0      James Cameron                   723.0  Action|Adventure|Fantasy|Sci-Fi
# 1     Gore Verbinski                   302.0         Action|Adventure|Fantasy
# 2         Sam Mendes                   602.0        Action|Adventure|Thriller
# 3  Christopher Nolan                   813.0                  Action|Thriller
# 5     Andrew Stanton                   462.0          Action|Adventure|Sci-Fi
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 5     Daryl Sabara                               John Carter
#
#    num_voted_users  num_user_for_reviews language  title_year  imdb_score  \
# ...

# %%
# Write your code for extracting the first two genres of each movie here

movies[["genre_1","genre_2"]]= movies["genres"].apply(lambda x: pd.Series([x.split("|")[0], x.split("|")[1] 
                                                      if len(x.split("|")) >1 else x.split("|")[0]])) 
# Steps done for above code :
# Split the 'genres' column by "|" delimiter into a list of genres
# Created new columns 'genre_1' and 'genre_2' by extracting the first and second genres
# Duplicated the first genre into 'genre_2' if only one genre was present

movies.head()
# Out:
#        director_name  num_critic_for_reviews                           genres  \
# 0      James Cameron                   723.0  Action|Adventure|Fantasy|Sci-Fi
# 1     Gore Verbinski                   302.0         Action|Adventure|Fantasy
# 2         Sam Mendes                   602.0        Action|Adventure|Thriller
# 3  Christopher Nolan                   813.0                  Action|Thriller
# 5     Andrew Stanton                   462.0          Action|Adventure|Sci-Fi
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
# 3        Tom Hardy                     The Dark Knight Rises
# 5     Daryl Sabara                               John Carter
#
#    num_voted_users  num_user_for_reviews language  title_year  imdb_score  \
# ...

# %%
# Grouping the dataframe using genre_1 as the primary column and genre_2 as the secondary column.

movies_by_segment = movies.groupby(["genre_1","genre_2"]).size()
movies_by_segment
# Out:
# genre_1   genre_2
# Action    Action         6
#           Adventure    412
#           Animation      8
#           Biography     14
#           Comedy       131
#                       ...
# Romance   Sci-Fi         1
# Sci-Fi    Sci-Fi         1
#           Thriller       7
# Thriller  Thriller       3
# Western   Western        3
# Length: 103, dtype: int64

# %%
# The 5 most popular combo of genres by finding the mean of the gross values using the gross column and store them in a new dataframe named PopGenre.

PopGenre = movies.groupby(["genre_1","genre_2"])["profit"].mean().sort_values(ascending=False).head(5)
PopGenre.to_frame()
# Out:
#                        profit
# genre_1   genre_2
# Family    Sci-Fi   424.449459
# Adventure Sci-Fi   124.127758
# Musical   Romance   88.894500
# Animation Family    47.426929
# Comedy    Western   39.803641

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
#Inspecting the actor_1_name Column for future operations.

movies.head(3)
# Out:
#     director_name  num_critic_for_reviews                           genres  \
# 0   James Cameron                   723.0  Action|Adventure|Fantasy|Sci-Fi
# 1  Gore Verbinski                   302.0         Action|Adventure|Fantasy
# 2      Sam Mendes                   602.0        Action|Adventure|Thriller
#
#       actor_1_name                                movie_title  \
# 0      CCH Pounder                                    Avatar
# 1      Johnny Depp  Pirates of the Caribbean: At World's End
# 2  Christoph Waltz                                   Spectre
#
#    num_voted_users  num_user_for_reviews language  title_year  imdb_score  \
# 0           886204                3054.0  English      2009.0         7.9
# 1           471220                1238.0  English      2007.0         7.1
# 2           275868                 994.0  English      2015.0         6.8
#
#    movie_facebook_likes  gross in million $  budget in million $      profit  \
# ...

# %%
# Write your code for creating three new dataframes here

Meryl_Streep = movies[movies["actor_1_name"] == "Meryl Streep"]
Meryl_Streep.head()
# Out:
#        director_name  num_critic_for_reviews                           genres  \
# 410     Nancy Meyers                   187.0             Comedy|Drama|Romance
# 1106   Curtis Hanson                    42.0  Action|Adventure|Crime|Thriller
# 1204     Nora Ephron                   252.0          Biography|Drama|Romance
# 1408   David Frankel                   208.0             Comedy|Drama|Romance
# 1483  Robert Redford                   227.0               Drama|Thriller|War
#
#       actor_1_name             movie_title  num_voted_users  \
# 410   Meryl Streep       It's Complicated             69860
# 1106  Meryl Streep         The River Wild             32544
# 1204  Meryl Streep          Julie & Julia             79264
# 1408  Meryl Streep  The Devil Wears Prada            286178
# 1483  Meryl Streep        Lions for Lambs             41170
#
#       num_user_for_reviews language  title_year  imdb_score  \
# 410                  214.0  English      2009.0         6.6
# ...

# %%
Leo_Caprio = movies[movies["actor_1_name"] == "Leonardo DiCaprio"]
Leo_Caprio.head()
# Out:
#              director_name  num_critic_for_reviews  \
# 26           James Cameron                   315.0
# 50            Baz Luhrmann                   490.0
# 97       Christopher Nolan                   642.0
# 179  Alejandro G. Iñárritu                   556.0
# 257        Martin Scorsese                   267.0
#
#                                genres       actor_1_name        movie_title  \
# 26                      Drama|Romance  Leonardo DiCaprio           Titanic
# 50                      Drama|Romance  Leonardo DiCaprio  The Great Gatsby
# 97   Action|Adventure|Sci-Fi|Thriller  Leonardo DiCaprio         Inception
# 179  Adventure|Drama|Thriller|Western  Leonardo DiCaprio      The Revenant
# 257                   Biography|Drama  Leonardo DiCaprio       The Aviator
#
#      num_voted_users  num_user_for_reviews language  title_year  imdb_score  \
# 26            793059                2528.0  English      1997.0         7.7
# ...

# %%
Brad_Pitt = movies[movies["actor_1_name"] == "Brad Pitt"]
Brad_Pitt.head()
# Out:
#          director_name  num_critic_for_reviews  \
# 101      David Fincher                   362.0
# 147  Wolfgang Petersen                   220.0
# 254  Steven Soderbergh                   198.0
# 255         Doug Liman                   233.0
# 382         Tony Scott                   142.0
#
#                                    genres actor_1_name  \
# 101                 Drama|Fantasy|Romance    Brad Pitt
# 147                             Adventure    Brad Pitt
# 254                        Crime|Thriller    Brad Pitt
# 255  Action|Comedy|Crime|Romance|Thriller    Brad Pitt
# 382                 Action|Crime|Thriller    Brad Pitt
#
#                               movie_title  num_voted_users  \
# 101  The Curious Case of Benjamin Button            459346
# 147                                 Troy            381672
# 254                       Ocean's Twelve            284852
# 255                     Mr. & Mrs. Smith            348861
# ...

# %%
# Write your code for combining the three dataframes here

Combined =pd.concat( [Meryl_Streep,Leo_Caprio,Brad_Pitt], axis = 0,ignore_index =True)
Combined
# Out:
#             director_name  num_critic_for_reviews  \
# 0            Nancy Meyers                   187.0
# 1           Curtis Hanson                    42.0
# 2             Nora Ephron                   252.0
# 3           David Frankel                   208.0
# 4          Robert Redford                   227.0
# 5          Sydney Pollack                    66.0
# 6           David Frankel                   234.0
# 7           Carl Franklin                    64.0
# 8          Stephen Daldry                   174.0
# 9          Phyllida Lloyd                   331.0
# 10          Robert Altman                   211.0
# 11          James Cameron                   315.0
# 12           Baz Luhrmann                   490.0
# 13      Christopher Nolan                   642.0
# 14  Alejandro G. Iñárritu                   556.0
# 15        Martin Scorsese                   267.0
# 16      Quentin Tarantino                   765.0
# 17           Edward Zwick                   166.0
# ...

# %%
# Write your code for grouping the combined dataframe here

Combined.groupby("actor_1_name")

# %%
# Write the code for finding the mean of critic reviews and audience reviews here

# Mean of the num_critic_for_reviews and the actor having the highest mean is:
print(Combined.groupby("actor_1_name")["num_critic_for_reviews"].mean().to_frame())
Combined.groupby("actor_1_name")["num_critic_for_reviews"].mean().idxmax()
# Out:
#                    num_critic_for_reviews
# actor_1_name
# Brad Pitt                      245.000000
# Leonardo DiCaprio              330.190476
# Meryl Streep                   181.454545
# 'Leonardo DiCaprio'

# %%
# Mean of the num_user_for_reviews and the actor having the highest mean is:

print(Combined.groupby("actor_1_name")["num_user_for_reviews"].mean().to_frame())
Combined.groupby("actor_1_name")["num_user_for_reviews"].mean().idxmax()
# Out:
#                    num_user_for_reviews
# actor_1_name
# Brad Pitt                    742.352941
# Leonardo DiCaprio            914.476190
# Meryl Streep                 297.181818
# 'Leonardo DiCaprio'

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!
